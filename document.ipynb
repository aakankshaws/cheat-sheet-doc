# %% [markdown]
# Pandas functions and maps cheat sheet

# %%
import pandas as pd
reviews = pd.read_csv("data/iris.csv", index_col=0)
reviews.head()
# Out:
#               sepal_width  petal_length  petal_width species
# sepal_length
# 5.1                   3.5           1.4          0.2      se
# 4.9                   3.0           1.4          0.2  setosa
# 4.7                   3.2           1.3          0.2  setosa
# 4.6                   3.1           1.5          0.2  setosa
# 5.0                   3.6           1.4          0.2  setosa

# %% [markdown]
# ****pandas provides many simple "summary" of the data****

# %%
reviews.describe()
# Out:
#        sepal_width  petal_length  petal_width
# count   150.000000    150.000000   150.000000
# mean      3.054000      3.758667     1.198667
# std       0.433594      1.764420     0.763161
# min       2.000000      1.000000     0.100000
# 25%       2.800000      1.600000     0.300000
# 50%       3.000000      4.350000     1.300000
# 75%       3.300000      5.100000     1.800000
# max       4.400000      6.900000     2.500000

# %%
reviews.species.describe()
# Out:
# count            150
# unique             4
# top       versicolor
# freq              50
# Name: species, dtype: object

# %%
reviews.species.unique()
# Out:
# array(['se', 'setosa', 'versicolor', 'virginica'], dtype=object)

# %% [markdown]
# **To see a list of unique values and how often they occur in the dataset, we can use the value_counts method:**

# %%
reviews.species.value_counts()
# Out:
# versicolor    50
# virginica     50
# setosa        49
# se             1
# Name: species, dtype: int64

# %% [markdown]
# **Maps**

# %%
review_petal_length_mean = reviews.petal_length.mean()
reviews.petal_length.map(lambda p: p - review_petal_length_mean)

# %% [markdown]
# **The DataFrame apply function can be used to do the same thing across columns, on the level of the entire dataset. Thus apply takes a DataFrame as input.**

# %%
def remean_petal_length(srs):
    srs.petal_length = srs.petal_length - review_petal_length_mean
    return srs

reviews.apply(remean_petal_length, axis='columns')
# Out:
#               sepal_width  petal_length  petal_width    species
# sepal_length
# 5.1                   3.5     -2.358667          0.2         se
# 4.9                   3.0     -2.358667          0.2     setosa
# 4.7                   3.2     -2.458667          0.2     setosa
# 4.6                   3.1     -2.258667          0.2     setosa
# 5.0                   3.6     -2.358667          0.2     setosa
# 5.4                   3.9     -2.058667          0.4     setosa
# 4.6                   3.4     -2.358667          0.3     setosa
# 5.0                   3.4     -2.258667          0.2     setosa
# 4.4                   2.9     -2.358667          0.2     setosa
# 4.9                   3.1     -2.258667          0.1     setosa
# 5.4                   3.7     -2.258667          0.2     setosa
# 4.8                   3.4     -2.158667          0.2     setosa
# 4.8                   3.0     -2.358667          0.1     setosa
# 4.3                   3.0     -2.658667          0.1     setosa
# 5.8                   4.0     -2.558667          0.2     setosa
# 5.7                   4.4     -2.258667          0.4     setosa
# 5.4                   3.9     -2.458667          0.4     setosa
# 5.1                   3.5     -2.358667          0.3     setosa
# 5.7                   3.8     -2.058667          0.3     setosa
# 5.1                   3.8     -2.258667          0.3     setosa
# 5.4                   3.4     -2.058667          0.2     setosa
# 5.1                   3.7     -2.258667          0.4     setosa
# 4.6                   3.6     -2.758667          0.2     setosa
# 5.1                   3.3     -2.058667          0.5     setosa
# 4.8                   3.4     -1.858667          0.2     setosa
# 5.0                   3.0     -2.158667          0.2     setosa
# 5.0                   3.4     -2.158667          0.4     setosa
# 5.2                   3.5     -2.258667          0.2     setosa
# 5.2                   3.4     -2.358667          0.2     setosa
# 4.7                   3.2     -2.158667          0.2     setosa
# ...                   ...           ...          ...        ...
# 6.9                   3.2      1.941333          2.3  virginica
# 5.6                   2.8      1.141333          2.0  virginica
# 7.7                   2.8      2.941333          2.0  virginica
# 6.3                   2.7      1.141333          1.8  virginica
# 6.7                   3.3      1.941333          2.1  virginica
# 7.2                   3.2      2.241333          1.8  virginica
# 6.2                   2.8      1.041333          1.8  virginica
# 6.1                   3.0      1.141333          1.8  virginica
# 6.4                   2.8      1.841333          2.1  virginica
# 7.2                   3.0      2.041333          1.6  virginica
# 7.4                   2.8      2.341333          1.9  virginica
# 7.9                   3.8      2.641333          2.0  virginica
# 6.4                   2.8      1.841333          2.2  virginica
# 6.3                   2.8      1.341333          1.5  virginica
# 6.1                   2.6      1.841333          1.4  virginica
# 7.7                   3.0      2.341333          2.3  virginica
# 6.3                   3.4      1.841333          2.4  virginica
# 6.4                   3.1      1.741333          1.8  virginica
# 6.0                   3.0      1.041333          1.8  virginica
# 6.9                   3.1      1.641333          2.1  virginica
# 6.7                   3.1      1.841333          2.4  virginica
# 6.9                   3.1      1.341333          2.3  virginica
# 5.8                   2.7      1.341333          1.9  virginica
# 6.8                   3.2      2.141333          2.3  virginica
# 6.7                   3.3      1.941333          2.5  virginica
# 6.7                   3.0      1.441333          2.3  virginica
# 6.3                   2.5      1.241333          1.9  virginica
# 6.5                   3.0      1.441333          2.0  virginica
# 6.2                   3.4      1.641333          2.3  virginica
# 5.9                   3.0      1.341333          1.8  virginica
#
# [150 rows x 4 columns]

# %%
review_petal_length_mean = reviews.petal_length.mean()
reviews.petal_length - review_petal_length_mean
# Out:
# sepal_length
# 5.1   -2.358667
# 4.9   -2.358667
# 4.7   -2.458667
# 4.6   -2.258667
# 5.0   -2.358667
# 5.4   -2.058667
# 4.6   -2.358667
# 5.0   -2.258667
# 4.4   -2.358667
# 4.9   -2.258667
# 5.4   -2.258667
# 4.8   -2.158667
# 4.8   -2.358667
# 4.3   -2.658667
# 5.8   -2.558667
# 5.7   -2.258667
# 5.4   -2.458667
# 5.1   -2.358667
# 5.7   -2.058667
# 5.1   -2.258667
# 5.4   -2.058667
# 5.1   -2.258667
# 4.6   -2.758667
# 5.1   -2.058667
# 4.8   -1.858667
# 5.0   -2.158667
# 5.0   -2.158667
# 5.2   -2.258667
# 5.2   -2.358667
# 4.7   -2.158667
#          ...
# 6.9    1.941333
# 5.6    1.141333
# 7.7    2.941333
# 6.3    1.141333
# 6.7    1.941333
# 7.2    2.241333
# 6.2    1.041333
# 6.1    1.141333
# 6.4    1.841333
# 7.2    2.041333
# 7.4    2.341333
# 7.9    2.641333
# 6.4    1.841333
# 6.3    1.341333
# 6.1    1.841333
# 7.7    2.341333
# 6.3    1.841333
# 6.4    1.741333
# 6.0    1.041333
# 6.9    1.641333
# 6.7    1.841333
# 6.9    1.341333
# 5.8    1.341333
# 6.8    2.141333
# 6.7    1.941333
# 6.7    1.441333
# 6.3    1.241333
# 6.5    1.441333
# 6.2    1.641333
# 5.9    1.341333
# Name: petal_length, Length: 150, dtype: float64

# %%
reviews.species + " - " + reviews.species
# Out:
# sepal_length
# 5.1                  se - se
# 4.9          setosa - setosa
# 4.7          setosa - setosa
# 4.6          setosa - setosa
# 5.0          setosa - setosa
# 5.4          setosa - setosa
# 4.6          setosa - setosa
# 5.0          setosa - setosa
# 4.4          setosa - setosa
# 4.9          setosa - setosa
# 5.4          setosa - setosa
# 4.8          setosa - setosa
# 4.8          setosa - setosa
# 4.3          setosa - setosa
# 5.8          setosa - setosa
# 5.7          setosa - setosa
# 5.4          setosa - setosa
# 5.1          setosa - setosa
# 5.7          setosa - setosa
# 5.1          setosa - setosa
# 5.4          setosa - setosa
# 5.1          setosa - setosa
# 4.6          setosa - setosa
# 5.1          setosa - setosa
# 4.8          setosa - setosa
# 5.0          setosa - setosa
# 5.0          setosa - setosa
# 5.2          setosa - setosa
# 5.2          setosa - setosa
# 4.7          setosa - setosa
#                ...
# 6.9    virginica - virginica
# 5.6    virginica - virginica
# 7.7    virginica - virginica
# 6.3    virginica - virginica
# 6.7    virginica - virginica
# 7.2    virginica - virginica
# 6.2    virginica - virginica
# 6.1    virginica - virginica
# 6.4    virginica - virginica
# 7.2    virginica - virginica
# 7.4    virginica - virginica
# 7.9    virginica - virginica
# 6.4    virginica - virginica
# 6.3    virginica - virginica
# 6.1    virginica - virginica
# 7.7    virginica - virginica
# 6.3    virginica - virginica
# 6.4    virginica - virginica
# 6.0    virginica - virginica
# 6.9    virginica - virginica
# 6.7    virginica - virginica
# 6.9    virginica - virginica
# 5.8    virginica - virginica
# 6.8    virginica - virginica
# 6.7    virginica - virginica
# 6.7    virginica - virginica
# 6.3    virginica - virginica
# 6.5    virginica - virginica
# 6.2    virginica - virginica
# 5.9    virginica - virginica
# Name: species, Length: 150, dtype: object
